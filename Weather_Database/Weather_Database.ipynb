# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
import time
from datetime import datetime
import requests
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combos
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high = 180.000, size =2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the lats and longs to a list.
coordinates = list(lat_lngs)

# %%
#create a list for holding the cities
cities=[]
# identify the nearest city for each lat & long combo
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we add it to the list of cities.
    if city not in cities:
        cities.append(city)
        
#print the city count to confirm sufficient count.
len(cities)
# Out:
# 716

# %%
#set base url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key

# %%
#Create an empty list to hold the weather data
city_data=[]
#Print the beginning of the logging.
print("Beginning Data Retrieval   ")
print("---------------------------")

#Create counters.
record_count = 1
set_count = 1

#Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i>=50):
        set_count+=1
        record_count=1
        time.sleep(60)
    #create endpoint URL with each city.
    city_url = url+"&q="+city.replace(" ","+")
    
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to rcord count.
    record_count+=1
    
# Run an API request for each of the cities.
    try:
        city_weather = requests.get(city_url).json()
        #Parse the JSON and retrieve data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                        "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | beringovskiy
# Processing Record 3 of Set 1 | fuengirola
# Processing Record 4 of Set 1 | lompoc
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | half moon bay
# Processing Record 8 of Set 1 | prince rupert
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | souillac
# Processing Record 13 of Set 1 | lata
# Processing Record 14 of Set 1 | pahrump
# Processing Record 15 of Set 1 | arivonimamo
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | vostok
# Processing Record 18 of Set 1 | qaanaaq
# Processing Record 19 of Set 1 | cockburn town
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | lebu
# Processing Record 22 of Set 1 | san ramon de la nueva oran
# Processing Record 23 of Set 1 | gawler
# Processing Record 24 of Set 1 | arraial do cabo
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | craigieburn
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | stornoway
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | ilulissat
# Processing Record 32 of Set 1 | iqaluit
# Processing Record 33 of Set 1 | venice
# Processing Record 34 of Set 1 | sibolga
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | lermontovka
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 1 | ilo
# Processing Record 42 of Set 1 | henties bay
# Processing Record 43 of Set 1 | lundazi
# Processing Record 44 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 1 | kruisfontein
# Processing Record 46 of Set 1 | talnakh
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | nanortalik
# Processing Record 49 of Set 1 | sao filipe
# Processing Record 50 of Set 1 | kedougou
# Processing Record 1 of Set 2 | krasnoborsk
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | kununurra
# Processing Record 4 of Set 2 | pierre
# Processing Record 5 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 2 | dongsheng
# Processing Record 7 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 2 | khatanga
# Processing Record 9 of Set 2 | kaeo
# Processing Record 10 of Set 2 | hasaki
# Processing Record 11 of Set 2 | clyde river
# Processing Record 12 of Set 2 | bonavista
# Processing Record 13 of Set 2 | krasnoselkup
# Processing Record 14 of Set 2 | sobolevo
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | palmas
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | dingle
# Processing Record 20 of Set 2 | cape town
# Processing Record 21 of Set 2 | ponta do sol
# Processing Record 22 of Set 2 | barcelos
# Processing Record 23 of Set 2 | iquitos
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | nishihara
# Processing Record 27 of Set 2 | puteyets
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | innisfail
# Processing Record 30 of Set 2 | nuuk
# Processing Record 31 of Set 2 | oriximina
# Processing Record 32 of Set 2 | nome
# Processing Record 33 of Set 2 | kaniama
# Processing Record 34 of Set 2 | shizuishan
# Processing Record 35 of Set 2 | pout
# Processing Record 36 of Set 2 | kirkuk
# Processing Record 37 of Set 2 | saint-philippe
# Processing Record 38 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | dunkirk
# Processing Record 41 of Set 2 | castro
# Processing Record 42 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 2 | korla
# Processing Record 44 of Set 2 | ormara
# Processing Record 45 of Set 2 | butaritari
# Processing Record 46 of Set 2 | sisimiut
# Processing Record 47 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 2 | cabo san lucas
# Processing Record 49 of Set 2 | watertown
# Processing Record 50 of Set 2 | kaa-khem
# Processing Record 1 of Set 3 | galle
# Processing Record 2 of Set 3 | blackwater
# Processing Record 3 of Set 3 | sidareja
# Processing Record 4 of Set 3 | atuona
# Processing Record 5 of Set 3 | provideniya
# Processing Record 6 of Set 3 | svetlogorsk
# Processing Record 7 of Set 3 | hamilton
# Processing Record 8 of Set 3 | yangambi
# Processing Record 9 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 3 | san policarpo
# Processing Record 11 of Set 3 | staunton
# Processing Record 12 of Set 3 | umm lajj
# Processing Record 13 of Set 3 | naron
# Processing Record 14 of Set 3 | dikson
# Processing Record 15 of Set 3 | colac
# Processing Record 16 of Set 3 | luderitz
# Processing Record 17 of Set 3 | san roque
# Processing Record 18 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 3 | kawalu
# Processing Record 20 of Set 3 | graham
# Processing Record 21 of Set 3 | taltal
# Processing Record 22 of Set 3 | beira
# Processing Record 23 of Set 3 | hobart
# Processing Record 24 of Set 3 | kapaa
# Processing Record 25 of Set 3 | tecolutla
# Processing Record 26 of Set 3 | jamestown
# Processing Record 27 of Set 3 | aklavik
# Processing Record 28 of Set 3 | cherskiy
# Processing Record 29 of Set 3 | manggar
# Processing Record 30 of Set 3 | bambous virieux
# Processing Record 31 of Set 3 | yellowknife
# Processing Record 32 of Set 3 | barrow
# Processing Record 33 of Set 3 | atar
# Processing Record 34 of Set 3 | yerbogachen
# Processing Record 35 of Set 3 | tahe
# Processing Record 36 of Set 3 | urusha
# Processing Record 37 of Set 3 | tual
# Processing Record 38 of Set 3 | windsor
# Processing Record 39 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 3 | nyrob
# Processing Record 41 of Set 3 | baykit
# Processing Record 42 of Set 3 | inuvik
# Processing Record 43 of Set 3 | mahabaleshwar
# Processing Record 44 of Set 3 | guanare
# Processing Record 45 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 3 | spencer
# Processing Record 47 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 3 | isangel
# Processing Record 49 of Set 3 | meulaboh
# Processing Record 50 of Set 3 | victoria
# Processing Record 1 of Set 4 | zhovti vody
# Processing Record 2 of Set 4 | preston
# Processing Record 3 of Set 4 | qui nhon
# Processing Record 4 of Set 4 | zaozhuang
# Processing Record 5 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 4 | waiuku
# Processing Record 7 of Set 4 | cidreira
# Processing Record 8 of Set 4 | san cristobal
# Processing Record 9 of Set 4 | bac lieu
# Processing Record 10 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 11 of Set 4 | namatanai
# Processing Record 12 of Set 4 | ancud
# Processing Record 13 of Set 4 | mar del plata
# Processing Record 14 of Set 4 | klaksvik
# Processing Record 15 of Set 4 | orlik
# Processing Record 16 of Set 4 | qaqortoq
# Processing Record 17 of Set 4 | chizhou
# Processing Record 18 of Set 4 | naryan-mar
# Processing Record 19 of Set 4 | kamaishi
# Processing Record 20 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 21 of Set 4 | sitka
# Processing Record 22 of Set 4 | naze
# Processing Record 23 of Set 4 | saldanha
# Processing Record 24 of Set 4 | taoudenni
# Processing Record 25 of Set 4 | bethel
# Processing Record 26 of Set 4 | airai
# Processing Record 27 of Set 4 | raudeberg
# Processing Record 28 of Set 4 | asau
# Processing Record 29 of Set 4 | praia
# Processing Record 30 of Set 4 | mount gambier
# Processing Record 31 of Set 4 | codrington
# Processing Record 32 of Set 4 | coxim
# Processing Record 33 of Set 4 | adrar
# Processing Record 34 of Set 4 | laguna
# Processing Record 35 of Set 4 | rincon
# Processing Record 36 of Set 4 | bathsheba
# Processing Record 37 of Set 4 | schruns
# Processing Record 38 of Set 4 | sur
# Processing Record 39 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 4 | mecca
# Processing Record 41 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 42 of Set 4 | kupang
# Processing Record 43 of Set 4 | belaya gora
# Processing Record 44 of Set 4 | george town
# Processing Record 45 of Set 4 | kaitangata
# Processing Record 46 of Set 4 | luau
# Processing Record 47 of Set 4 | jennings
# Processing Record 48 of Set 4 | urubicha
# Processing Record 49 of Set 4 | salta
# Processing Record 50 of Set 4 | tecoanapa
# Processing Record 1 of Set 5 | olafsvik
# Processing Record 2 of Set 5 | kathmandu
# Processing Record 3 of Set 5 | saint george
# Processing Record 4 of Set 5 | kabinda
# Processing Record 5 of Set 5 | arman
# Processing Record 6 of Set 5 | san angelo
# Processing Record 7 of Set 5 | sorland
# Processing Record 8 of Set 5 | jefferson city
# Processing Record 9 of Set 5 | sebezh
# Processing Record 10 of Set 5 | deyang
# Processing Record 11 of Set 5 | hofn
# Processing Record 12 of Set 5 | kavieng
# Processing Record 13 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 5 | hami
# Processing Record 15 of Set 5 | severo-kurilsk
# Processing Record 16 of Set 5 | vung tau
# Processing Record 17 of Set 5 | redmond
# Processing Record 18 of Set 5 | mokokchung
# Processing Record 19 of Set 5 | santa isabel do rio negro
# Processing Record 20 of Set 5 | alpena
# Processing Record 21 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 5 | palma di montechiaro
# Processing Record 23 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 24 of Set 5 | shubarshi
# Processing Record 25 of Set 5 | plettenberg bay
# Processing Record 26 of Set 5 | namibe
# Processing Record 27 of Set 5 | natulongan
# City not found. Skipping...
# Processing Record 28 of Set 5 | mount isa
# Processing Record 29 of Set 5 | todos santos
# Processing Record 30 of Set 5 | luba
# Processing Record 31 of Set 5 | shelburne
# Processing Record 32 of Set 5 | jumla
# Processing Record 33 of Set 5 | polunochnoye
# Processing Record 34 of Set 5 | parrita
# Processing Record 35 of Set 5 | esperance
# Processing Record 36 of Set 5 | necochea
# Processing Record 37 of Set 5 | wanning
# Processing Record 38 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 39 of Set 5 | sinfra
# Processing Record 40 of Set 5 | kamenka
# Processing Record 41 of Set 5 | zelenoborskiy
# Processing Record 42 of Set 5 | concarneau
# Processing Record 43 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 5 | muravlenko
# Processing Record 45 of Set 5 | biak
# Processing Record 46 of Set 5 | abha
# Processing Record 47 of Set 5 | lavrentiya
# Processing Record 48 of Set 5 | quatre cocos
# Processing Record 49 of Set 5 | rabat
# Processing Record 50 of Set 5 | prigorodnyy
# Processing Record 1 of Set 6 | ahipara
# Processing Record 2 of Set 6 | iranshahr
# Processing Record 3 of Set 6 | saskylakh
# Processing Record 4 of Set 6 | ayagoz
# Processing Record 5 of Set 6 | lorengau
# Processing Record 6 of Set 6 | lianzhou
# Processing Record 7 of Set 6 | dzaoudzi
# Processing Record 8 of Set 6 | katsuura
# Processing Record 9 of Set 6 | shahrud
# Processing Record 10 of Set 6 | tamale
# Processing Record 11 of Set 6 | celina
# Processing Record 12 of Set 6 | beitbridge
# Processing Record 13 of Set 6 | ituporanga
# Processing Record 14 of Set 6 | geraldton
# Processing Record 15 of Set 6 | alofi
# Processing Record 16 of Set 6 | almaznyy
# Processing Record 17 of Set 6 | melfi
# Processing Record 18 of Set 6 | tairua
# Processing Record 19 of Set 6 | constantine
# Processing Record 20 of Set 6 | port hedland
# Processing Record 21 of Set 6 | sao felix do xingu
# Processing Record 22 of Set 6 | torres
# Processing Record 23 of Set 6 | asandh
# Processing Record 24 of Set 6 | vanimo
# Processing Record 25 of Set 6 | kahului
# Processing Record 26 of Set 6 | tevaitoa
# Processing Record 27 of Set 6 | amuntai
# Processing Record 28 of Set 6 | port hardy
# Processing Record 29 of Set 6 | la asuncion
# Processing Record 30 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 31 of Set 6 | niksar
# Processing Record 32 of Set 6 | grand gaube
# Processing Record 33 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 6 | hervey bay
# Processing Record 35 of Set 6 | saint-augustin
# Processing Record 36 of Set 6 | kodinsk
# Processing Record 37 of Set 6 | florianopolis
# Processing Record 38 of Set 6 | los algarrobos
# Processing Record 39 of Set 6 | flinders
# Processing Record 40 of Set 6 | wenling
# Processing Record 41 of Set 6 | moose factory
# Processing Record 42 of Set 6 | vila velha
# Processing Record 43 of Set 6 | tacuarembo
# Processing Record 44 of Set 6 | abu kamal
# Processing Record 45 of Set 6 | ferkessedougou
# Processing Record 46 of Set 6 | eureka
# Processing Record 47 of Set 6 | bandarbeyla
# Processing Record 48 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 6 | ribeira grande
# Processing Record 50 of Set 6 | prestea
# Processing Record 1 of Set 7 | seoul
# Processing Record 2 of Set 7 | vestmannaeyjar
# Processing Record 3 of Set 7 | bojnurd
# Processing Record 4 of Set 7 | general pico
# Processing Record 5 of Set 7 | antalaha
# Processing Record 6 of Set 7 | saryg-sep
# Processing Record 7 of Set 7 | malakal
# Processing Record 8 of Set 7 | mahebourg
# Processing Record 9 of Set 7 | andenes
# Processing Record 10 of Set 7 | kushmurun
# Processing Record 11 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 7 | caravelas
# Processing Record 13 of Set 7 | farafangana
# Processing Record 14 of Set 7 | skjaerhollen
# City not found. Skipping...
# Processing Record 15 of Set 7 | jiaozuo
# Processing Record 16 of Set 7 | ust-tsilma
# Processing Record 17 of Set 7 | agde
# Processing Record 18 of Set 7 | osoyoos
# Processing Record 19 of Set 7 | kalmunai
# Processing Record 20 of Set 7 | carnarvon
# Processing Record 21 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 22 of Set 7 | tabou
# Processing Record 23 of Set 7 | touros
# Processing Record 24 of Set 7 | charters towers
# Processing Record 25 of Set 7 | rosario do sul
# Processing Record 26 of Set 7 | talavera de la reina
# Processing Record 27 of Set 7 | jurm
# Processing Record 28 of Set 7 | ayr
# Processing Record 29 of Set 7 | paita
# Processing Record 30 of Set 7 | vardo
# Processing Record 31 of Set 7 | ocos
# Processing Record 32 of Set 7 | pisco
# Processing Record 33 of Set 7 | lyngseidet
# Processing Record 34 of Set 7 | mongo
# Processing Record 35 of Set 7 | avera
# Processing Record 36 of Set 7 | abu samrah
# Processing Record 37 of Set 7 | ostrovnoy
# Processing Record 38 of Set 7 | constitucion
# Processing Record 39 of Set 7 | east london
# Processing Record 40 of Set 7 | smidovich
# Processing Record 41 of Set 7 | christiana
# Processing Record 42 of Set 7 | upernavik
# Processing Record 43 of Set 7 | canico
# Processing Record 44 of Set 7 | dese
# Processing Record 45 of Set 7 | batagay
# Processing Record 46 of Set 7 | bengkulu
# Processing Record 47 of Set 7 | narsaq
# Processing Record 48 of Set 7 | brownsville
# Processing Record 49 of Set 7 | safaqis
# City not found. Skipping...
# Processing Record 50 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 1 of Set 8 | payakumbuh
# Processing Record 2 of Set 8 | yumen
# Processing Record 3 of Set 8 | severodvinsk
# Processing Record 4 of Set 8 | chapais
# Processing Record 5 of Set 8 | hilo
# Processing Record 6 of Set 8 | sabla
# Processing Record 7 of Set 8 | bukachacha
# Processing Record 8 of Set 8 | alekseyevsk
# Processing Record 9 of Set 8 | mapiripan
# Processing Record 10 of Set 8 | marau
# Processing Record 11 of Set 8 | dunedin
# Processing Record 12 of Set 8 | sivaki
# Processing Record 13 of Set 8 | ha tinh
# Processing Record 14 of Set 8 | pevek
# Processing Record 15 of Set 8 | vila franca do campo
# Processing Record 16 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 17 of Set 8 | kasane
# Processing Record 18 of Set 8 | tucuman
# Processing Record 19 of Set 8 | te anau
# Processing Record 20 of Set 8 | ardesen
# Processing Record 21 of Set 8 | paine
# Processing Record 22 of Set 8 | bushenyi
# Processing Record 23 of Set 8 | cabedelo
# Processing Record 24 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 25 of Set 8 | gundlupet
# Processing Record 26 of Set 8 | okha
# Processing Record 27 of Set 8 | faya
# Processing Record 28 of Set 8 | ust-maya
# Processing Record 29 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 30 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 8 | tourlaville
# Processing Record 32 of Set 8 | kakching
# Processing Record 33 of Set 8 | westport
# Processing Record 34 of Set 8 | matara
# Processing Record 35 of Set 8 | rawson
# Processing Record 36 of Set 8 | bacolod
# Processing Record 37 of Set 8 | zverinogolovskoye
# Processing Record 38 of Set 8 | novo aripuana
# Processing Record 39 of Set 8 | coquimbo
# Processing Record 40 of Set 8 | rocha
# Processing Record 41 of Set 8 | san patricio
# Processing Record 42 of Set 8 | fortuna
# Processing Record 43 of Set 8 | srednekolymsk
# Processing Record 44 of Set 8 | robertsport
# Processing Record 45 of Set 8 | aksarka
# Processing Record 46 of Set 8 | chulym
# Processing Record 47 of Set 8 | salalah
# Processing Record 48 of Set 8 | chumikan
# Processing Record 49 of Set 8 | ben tre
# Processing Record 50 of Set 8 | kefamenanu
# Processing Record 1 of Set 9 | gonzales
# Processing Record 2 of Set 9 | reading
# Processing Record 3 of Set 9 | isabela
# Processing Record 4 of Set 9 | road town
# Processing Record 5 of Set 9 | dunmore town
# Processing Record 6 of Set 9 | birjand
# Processing Record 7 of Set 9 | kaliua
# Processing Record 8 of Set 9 | kuliyapitiya
# Processing Record 9 of Set 9 | kibre mengist
# Processing Record 10 of Set 9 | sao joao da barra
# Processing Record 11 of Set 9 | gasa
# Processing Record 12 of Set 9 | pangai
# Processing Record 13 of Set 9 | severo-yeniseyskiy
# Processing Record 14 of Set 9 | vestmanna
# Processing Record 15 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 16 of Set 9 | los llanos de aridane
# Processing Record 17 of Set 9 | palmer
# Processing Record 18 of Set 9 | bonanza
# Processing Record 19 of Set 9 | tombouctou
# Processing Record 20 of Set 9 | port said
# Processing Record 21 of Set 9 | paris
# Processing Record 22 of Set 9 | pangnirtung
# Processing Record 23 of Set 9 | chokurdakh
# Processing Record 24 of Set 9 | mucurapo
# Processing Record 25 of Set 9 | port lincoln
# Processing Record 26 of Set 9 | vryburg
# Processing Record 27 of Set 9 | manali
# Processing Record 28 of Set 9 | siirt
# Processing Record 29 of Set 9 | altar
# Processing Record 30 of Set 9 | bulawayo
# Processing Record 31 of Set 9 | ginda
# Processing Record 32 of Set 9 | chicama
# Processing Record 33 of Set 9 | beloha
# Processing Record 34 of Set 9 | torbay
# Processing Record 35 of Set 9 | dordrecht
# Processing Record 36 of Set 9 | mbanza-ngungu
# Processing Record 37 of Set 9 | fairbanks
# Processing Record 38 of Set 9 | xinzhou
# Processing Record 39 of Set 9 | phalaborwa
# Processing Record 40 of Set 9 | dunn
# Processing Record 41 of Set 9 | peredovaya
# Processing Record 42 of Set 9 | tiznit
# Processing Record 43 of Set 9 | mogadishu
# Processing Record 44 of Set 9 | broken hill
# Processing Record 45 of Set 9 | hokitika
# Processing Record 46 of Set 9 | butterworth
# Processing Record 47 of Set 9 | namie
# Processing Record 48 of Set 9 | kelso
# Processing Record 49 of Set 9 | kenai
# Processing Record 50 of Set 9 | kuruman
# Processing Record 1 of Set 10 | marsabit
# Processing Record 2 of Set 10 | tabulbah
# City not found. Skipping...
# Processing Record 3 of Set 10 | coihaique
# Processing Record 4 of Set 10 | ulu-telyak
# Processing Record 5 of Set 10 | bismarck
# Processing Record 6 of Set 10 | hambantota
# Processing Record 7 of Set 10 | bloomingdale
# Processing Record 8 of Set 10 | castelnau-le-lez
# Processing Record 9 of Set 10 | grootfontein
# Processing Record 10 of Set 10 | flin flon
# Processing Record 11 of Set 10 | longyearbyen
# Processing Record 12 of Set 10 | haines junction
# Processing Record 13 of Set 10 | boffa
# Processing Record 14 of Set 10 | freeport
# Processing Record 15 of Set 10 | aksu
# Processing Record 16 of Set 10 | kelo
# Processing Record 17 of Set 10 | corrientes
# Processing Record 18 of Set 10 | labuhan
# Processing Record 19 of Set 10 | nadapuram
# Processing Record 20 of Set 10 | vikersund
# Processing Record 21 of Set 10 | kavali
# Processing Record 22 of Set 10 | caxito
# Processing Record 23 of Set 10 | dhidhdhoo
# Processing Record 24 of Set 10 | asyut
# Processing Record 25 of Set 10 | la ronge
# Processing Record 26 of Set 10 | taraz
# Processing Record 27 of Set 10 | vanavara
# Processing Record 28 of Set 10 | umba
# Processing Record 29 of Set 10 | bonthe
# Processing Record 30 of Set 10 | bisira
# Processing Record 31 of Set 10 | chiredzi
# Processing Record 32 of Set 10 | la rioja
# Processing Record 33 of Set 10 | la macarena
# Processing Record 34 of Set 10 | arlit
# Processing Record 35 of Set 10 | jimma
# Processing Record 36 of Set 10 | colares
# Processing Record 37 of Set 10 | northam
# Processing Record 38 of Set 10 | portree
# Processing Record 39 of Set 10 | broome
# Processing Record 40 of Set 10 | sola
# Processing Record 41 of Set 10 | sarangani
# Processing Record 42 of Set 10 | shetpe
# Processing Record 43 of Set 10 | marienburg
# Processing Record 44 of Set 10 | sembe
# Processing Record 45 of Set 10 | cairns
# Processing Record 46 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 10 | limoges
# Processing Record 48 of Set 10 | boa vista
# Processing Record 49 of Set 10 | scottsbluff
# Processing Record 50 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 1 of Set 11 | galesong
# Processing Record 2 of Set 11 | barkhan
# Processing Record 3 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 4 of Set 11 | samarai
# Processing Record 5 of Set 11 | aswan
# Processing Record 6 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 11 | tongren
# Processing Record 8 of Set 11 | hualmay
# Processing Record 9 of Set 11 | maldonado
# Processing Record 10 of Set 11 | mineiros
# Processing Record 11 of Set 11 | camacha
# Processing Record 12 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 13 of Set 11 | rangia
# Processing Record 14 of Set 11 | basco
# Processing Record 15 of Set 11 | napuro
# Processing Record 16 of Set 11 | miandrivazo
# Processing Record 17 of Set 11 | kieta
# Processing Record 18 of Set 11 | okhotsk
# Processing Record 19 of Set 11 | falam
# Processing Record 20 of Set 11 | sale
# Processing Record 21 of Set 11 | manacapuru
# Processing Record 22 of Set 11 | vao
# Processing Record 23 of Set 11 | santa luzia
# Processing Record 24 of Set 11 | sinnamary
# Processing Record 25 of Set 11 | bayeux
# Processing Record 26 of Set 11 | mehamn
# Processing Record 27 of Set 11 | general roca
# Processing Record 28 of Set 11 | altagracia de orituco
# Processing Record 29 of Set 11 | erdemli
# Processing Record 30 of Set 11 | souris
# Processing Record 31 of Set 11 | maturin
# Processing Record 32 of Set 11 | dawson creek
# Processing Record 33 of Set 11 | husavik
# Processing Record 34 of Set 11 | general cepeda
# Processing Record 35 of Set 11 | decatur
# Processing Record 36 of Set 11 | yar-sale
# Processing Record 37 of Set 11 | norman wells
# Processing Record 38 of Set 11 | port augusta
# Processing Record 39 of Set 11 | oktyabrskiy
# Processing Record 40 of Set 11 | harlingen
# Processing Record 41 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 42 of Set 11 | alta floresta
# Processing Record 43 of Set 11 | acapulco
# Processing Record 44 of Set 11 | gunjur
# Processing Record 45 of Set 11 | altay
# Processing Record 46 of Set 11 | leningradskiy
# Processing Record 47 of Set 11 | lasa
# Processing Record 48 of Set 11 | nalut
# Processing Record 49 of Set 11 | dudinka
# Processing Record 50 of Set 11 | maridi
# Processing Record 1 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 12 | aviles
# Processing Record 3 of Set 12 | port-gentil
# Processing Record 4 of Set 12 | roros
# Processing Record 5 of Set 12 | benghazi
# Processing Record 6 of Set 12 | lazurne
# Processing Record 7 of Set 12 | kondinskoye
# Processing Record 8 of Set 12 | ula
# Processing Record 9 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 10 of Set 12 | shimoda
# Processing Record 11 of Set 12 | nouadhibou
# Processing Record 12 of Set 12 | kichera
# Processing Record 13 of Set 12 | san francisco del mar
# Processing Record 14 of Set 12 | lucea
# Processing Record 15 of Set 12 | asfi
# Processing Record 16 of Set 12 | celestun
# Processing Record 17 of Set 12 | pervomayskiy
# Processing Record 18 of Set 12 | yakeshi
# Processing Record 19 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 12 | havoysund
# Processing Record 21 of Set 12 | sanming
# Processing Record 22 of Set 12 | gushikawa
# Processing Record 23 of Set 12 | erdenet
# Processing Record 24 of Set 12 | inhambane
# Processing Record 25 of Set 12 | sulurpeta
# City not found. Skipping...
# Processing Record 26 of Set 12 | banda aceh
# Processing Record 27 of Set 12 | asosa
# Processing Record 28 of Set 12 | sembakung
# Processing Record 29 of Set 12 | ojinaga
# Processing Record 30 of Set 12 | woodward
# Processing Record 31 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 12 | kismayo
# Processing Record 33 of Set 12 | sisophon
# Processing Record 34 of Set 12 | upington
# Processing Record 35 of Set 12 | neryungri
# Processing Record 36 of Set 12 | djibo
# Processing Record 37 of Set 12 | zhuhai
# Processing Record 38 of Set 12 | kedrovyy
# Processing Record 39 of Set 12 | zonguldak
# Processing Record 40 of Set 12 | loiza
# Processing Record 41 of Set 12 | oussouye
# Processing Record 42 of Set 12 | mlonggo
# Processing Record 43 of Set 12 | sioux lookout
# Processing Record 44 of Set 12 | ankang
# Processing Record 45 of Set 12 | aykhal
# Processing Record 46 of Set 12 | huaidian
# Processing Record 47 of Set 12 | sabha
# Processing Record 48 of Set 12 | crystal lake
# Processing Record 49 of Set 12 | finschhafen
# Processing Record 50 of Set 12 | richards bay
# Processing Record 1 of Set 13 | kindu
# Processing Record 2 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 13 | araceli
# Processing Record 4 of Set 13 | san jose
# Processing Record 5 of Set 13 | vuktyl
# Processing Record 6 of Set 13 | riberalta
# Processing Record 7 of Set 13 | mayumba
# Processing Record 8 of Set 13 | yatou
# Processing Record 9 of Set 13 | nabire
# Processing Record 10 of Set 13 | mogochin
# City not found. Skipping...
# Processing Record 11 of Set 13 | chernyshevskiy
# Processing Record 12 of Set 13 | stonewall
# Processing Record 13 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 14 of Set 13 | comodoro rivadavia
# Processing Record 15 of Set 13 | saint anthony
# Processing Record 16 of Set 13 | batagay-alyta
# Processing Record 17 of Set 13 | pala
# Processing Record 18 of Set 13 | cap-haitien
# Processing Record 19 of Set 13 | kalisz
# Processing Record 20 of Set 13 | dulce nombre de culmi
# Processing Record 21 of Set 13 | viransehir
# Processing Record 22 of Set 13 | carauari
# Processing Record 23 of Set 13 | songea
# Processing Record 24 of Set 13 | dallas
# Processing Record 25 of Set 13 | santa maria
# Processing Record 26 of Set 13 | phonhong
# Processing Record 27 of Set 13 | balkhash
# Processing Record 28 of Set 13 | preobrazheniye
# Processing Record 29 of Set 13 | manoel urbano
# Processing Record 30 of Set 13 | novobirilyussy
# Processing Record 31 of Set 13 | litovko
# Processing Record 32 of Set 13 | west warwick
# Processing Record 33 of Set 13 | asilah
# Processing Record 34 of Set 13 | safaga
# Processing Record 35 of Set 13 | liwale
# Processing Record 36 of Set 13 | don benito
# Processing Record 37 of Set 13 | whitehorse
# Processing Record 38 of Set 13 | kibala
# Processing Record 39 of Set 13 | sultanpur
# Processing Record 40 of Set 13 | casimiro de abreu
# Processing Record 41 of Set 13 | lugovskiy
# City not found. Skipping...
# Processing Record 42 of Set 13 | waingapu
# Processing Record 43 of Set 13 | khorinsk
# Processing Record 44 of Set 13 | clearwater
# Processing Record 45 of Set 13 | belyy
# Processing Record 46 of Set 13 | killybegs
# Processing Record 47 of Set 13 | pacifica
# Processing Record 48 of Set 13 | lyubech
# Processing Record 49 of Set 13 | puerto carreno
# Processing Record 50 of Set 13 | orange cove
# Processing Record 1 of Set 14 | winston-salem
# Processing Record 2 of Set 14 | viedma
# Processing Record 3 of Set 14 | nelas
# Processing Record 4 of Set 14 | espana
# Processing Record 5 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 14 | cururupu
# Processing Record 7 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 8 of Set 14 | aripuana
# Processing Record 9 of Set 14 | artyom
# Processing Record 10 of Set 14 | uribia
# Processing Record 11 of Set 14 | neiafu
# Processing Record 12 of Set 14 | challans
# Processing Record 13 of Set 14 | bubaque
# Processing Record 14 of Set 14 | ishigaki
# Processing Record 15 of Set 14 | roanoke rapids
# Processing Record 16 of Set 14 | chuy
# Processing Record 17 of Set 14 | barra do garcas
# Processing Record 18 of Set 14 | axim
# Processing Record 19 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 20 of Set 14 | kungurtug
# Processing Record 21 of Set 14 | buggenhout
# Processing Record 22 of Set 14 | batemans bay
# Processing Record 23 of Set 14 | rypefjord
# Processing Record 24 of Set 14 | ambovombe
# Processing Record 25 of Set 14 | crestview
# Processing Record 26 of Set 14 | pittsburg
# Processing Record 27 of Set 14 | roma
# Processing Record 28 of Set 14 | kirkwood
# Processing Record 29 of Set 14 | potgietersrus
# City not found. Skipping...
# Processing Record 30 of Set 14 | pacific grove
# Processing Record 31 of Set 14 | gizo
# Processing Record 32 of Set 14 | goiatuba
# Processing Record 33 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 34 of Set 14 | pampilhosa
# Processing Record 35 of Set 14 | rawlins
# Processing Record 36 of Set 14 | marawi
# Processing Record 37 of Set 14 | vinh
# Processing Record 38 of Set 14 | atasu
# Processing Record 39 of Set 14 | saurimo
# Processing Record 40 of Set 14 | linxia
# Processing Record 41 of Set 14 | bowen
# Processing Record 42 of Set 14 | riaba
# City not found. Skipping...
# Processing Record 43 of Set 14 | tres picos
# Processing Record 44 of Set 14 | ariquemes
# Processing Record 45 of Set 14 | lagoa
# Processing Record 46 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 47 of Set 14 | balkanabat
# Processing Record 48 of Set 14 | aloleng
# Processing Record 49 of Set 14 | paralimni
# Processing Record 50 of Set 14 | zhangye
# Processing Record 1 of Set 15 | leon
# Processing Record 2 of Set 15 | svetlaya
# Processing Record 3 of Set 15 | mao
# Processing Record 4 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 15 | khazar
# Processing Record 6 of Set 15 | sarakhs
# Processing Record 7 of Set 15 | gamba
# Processing Record 8 of Set 15 | havelock
# Processing Record 9 of Set 15 | alice springs
# Processing Record 10 of Set 15 | nhulunbuy
# Processing Record 11 of Set 15 | faanui
# Processing Record 12 of Set 15 | wajima
# Processing Record 13 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 14 of Set 15 | kloulklubed
# Processing Record 15 of Set 15 | awjilah
# Processing Record 16 of Set 15 | amarante do maranhao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Create the dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 0                   Tiksi      RU  71.6872  128.8694    -10.17       100
# 1            Beringovskiy      RU  63.0500  179.3167      0.86        78
# 2              Fuengirola      ES  36.5400   -4.6247     66.20        40
# 3                  Lompoc      US  34.6391 -120.4579     67.78        48
# 4             Tuktoyaktuk      CA  69.4541 -133.0374    -20.13       100
# ..                    ...     ...      ...       ...       ...       ...
# 649                Faanui      PF -16.4833 -151.7500     80.96        72
# 650                Wajima      JP  37.4000  136.9000     32.68       100
# 651           Kloulklubed      PW   7.0419  134.2556     82.90        78
# 652               Awjilah      LY  29.1081   21.2869     53.83        56
# 653  Amarante Do Maranhao      BR  -5.5667  -46.7422     74.25        91
#
#      Cloudiness  Wind Speed       Description
# 0           100        7.40   overcast clouds
# 1            99       19.55   overcast clouds
# 2             0       10.36         clear sky
# 3            75        4.00     broken clouds
# 4           100       10.02   overcast clouds
# ..          ...         ...               ...
# 649          60       15.75        light rain
# 650         100        2.30        light snow
# 651          82       18.59     broken clouds
# 652          49       15.12  scattered clouds
# 653         100        1.59   overcast clouds
#
# [654 rows x 9 columns]

# %%
#create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
#Export the City_data to a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
